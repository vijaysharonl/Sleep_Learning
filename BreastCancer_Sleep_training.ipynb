# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Set random seeds for reproducibility
seeds = [42, 999, 1234]
all_normal_accs = []
all_sleep_accs = []
all_dropout_accs = []

for seed in seeds:
    torch.manual_seed(seed)
    np.random.seed(seed)
    
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    # Hyperparameters
    num_epochs = 30
    batch_size = 32
    learning_rate = 0.001
    sleep_interval = 7
    sleep_duration = 1
    noise_intensity = 0.2
    partial_random = 0.3

    # Load and preprocess Breast Cancer dataset
    data = load_breast_cancer()
    X = StandardScaler().fit_transform(data.data)
    y = data.target

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)
    X_train = torch.tensor(X_train, dtype=torch.float32)
    y_train = torch.tensor(y_train, dtype=torch.long)
    X_test = torch.tensor(X_test, dtype=torch.float32)
    y_test = torch.tensor(y_test, dtype=torch.long)

    train_dataset = TensorDataset(X_train, y_train)
    test_dataset = TensorDataset(X_test, y_test)
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=batch_size)

    # Simple MLP Model with optional Dropout
    class MLP(nn.Module):
        def __init__(self, use_dropout=False):
            super(MLP, self).__init__()
            self.model = nn.Sequential(
                nn.Linear(30, 64),
                nn.ReLU(),
                nn.Linear(64, 32),
                nn.ReLU(),
                nn.Dropout(0.5) if use_dropout else nn.Identity(),
                nn.Linear(32, 2)
            )

        def forward(self, x):
            return self.model(x)

    # Initialize models
    model_normal = MLP().to(device)
    model_sleep = MLP().to(device)
    model_dropout = MLP(use_dropout=True).to(device)

    # Loss and optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer_normal = optim.Adam(model_normal.parameters(), lr=learning_rate)
    optimizer_sleep = optim.Adam(model_sleep.parameters(), lr=learning_rate)
    optimizer_dropout = optim.Adam(model_dropout.parameters(), lr=learning_rate)

    def train(model, optimizer, is_sleep_model=False, sleep_phase=False):
        model.train()
        total_loss = 0
        correct = 0
        total = 0

        for xb, yb in train_loader:
            xb, yb = xb.to(device), yb.to(device)

            if is_sleep_model and sleep_phase:
                noise = noise_intensity * torch.randn_like(xb)
                xb = torch.clamp(xb + noise, -3, 3)
                mask = torch.rand(yb.size(0), device=device) < partial_random
                yb[mask] = torch.randint(0, 2, (mask.sum(),), device=device)

            out = model(xb)
            loss = criterion(out, yb)

            optimizer.zero_grad()
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step()

            total_loss += loss.item()
            preds = torch.argmax(out, dim=1)
            correct += (preds == yb).sum().item()
            total += yb.size(0)

        return total_loss / len(train_loader), correct / total

    def test(model):
        model.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for xb, yb in test_loader:
                xb, yb = xb.to(device), yb.to(device)
                out = model(xb)
                preds = torch.argmax(out, dim=1)
                correct += (preds == yb).sum().item()
                total += yb.size(0)
        return correct / total

    # Training loop
    normal_accuracies = []
    sleep_accuracies = []
    test_accuracies_normal = []
    test_accuracies_sleep = []
    test_accuracies_dropout = []

    sleep_phase = False

    for epoch in range(num_epochs):
        if (epoch + 1) % sleep_interval == 0 and epoch > 0:
            sleep_phase = True
        elif (epoch + 1) % (sleep_interval + sleep_duration) == 0:
            sleep_phase = False

        loss_normal, acc_normal = train(model_normal, optimizer_normal)
        loss_dropout, acc_dropout = train(model_dropout, optimizer_dropout)

        if sleep_phase:
            loss_sleep, acc_sleep = train(model_sleep, optimizer_sleep, is_sleep_model=True, sleep_phase=True)
            _ = train(model_sleep, optimizer_sleep, is_sleep_model=False, sleep_phase=False)
        else:
            loss_sleep, acc_sleep = train(model_sleep, optimizer_sleep, is_sleep_model=False, sleep_phase=False)

        test_acc_normal = test(model_normal)
        test_acc_sleep = test(model_sleep)
        test_acc_dropout = test(model_dropout)

        normal_accuracies.append(acc_normal)
        sleep_accuracies.append(acc_sleep)
        test_accuracies_normal.append(test_acc_normal)
        test_accuracies_sleep.append(test_acc_sleep)
        test_accuracies_dropout.append(test_acc_dropout)

        print(f'Seed {seed} | Epoch [{epoch+1}/{num_epochs}]')
        print(f'Normal:  Loss {loss_normal:.4f} | Train Acc {acc_normal:.4f} | Test Acc {test_acc_normal:.4f}')
        print(f'Sleep:   Loss {loss_sleep:.4f} | Train Acc {acc_sleep:.4f} | Test Acc {test_acc_sleep:.4f} {"(Sleep Phase)" if sleep_phase else ""}')
        print(f'Dropout: Loss {loss_dropout:.4f} | Train Acc {acc_dropout:.4f} | Test Acc {test_acc_dropout:.4f}')
        print('-'*50)

    all_normal_accs.append(test_accuracies_normal)
    all_sleep_accs.append(test_accuracies_sleep)
    all_dropout_accs.append(test_accuracies_dropout)
# Out:
# Seed 42 | Epoch [1/30]
# Normal:  Loss 0.6328 | Train Acc 0.7956 | Test Acc 0.9649
# Sleep:   Loss 0.5938 | Train Acc 0.7824 | Test Acc 0.9035
# Dropout: Loss 0.6231 | Train Acc 0.6989 | Test Acc 0.8246
# --------------------------------------------------
# Seed 42 | Epoch [2/30]
# Normal:  Loss 0.4487 | Train Acc 0.9275 | Test Acc 0.9561
# Sleep:   Loss 0.4075 | Train Acc 0.9341 | Test Acc 0.9561
# Dropout: Loss 0.4862 | Train Acc 0.8527 | Test Acc 0.9211
# --------------------------------------------------
# Seed 42 | Epoch [3/30]
# Normal:  Loss 0.2663 | Train Acc 0.9341 | Test Acc 0.9561
# Sleep:   Loss 0.2337 | Train Acc 0.9451 | Test Acc 0.9561
# Dropout: Loss 0.3500 | Train Acc 0.9011 | Test Acc 0.9561
# --------------------------------------------------
# Seed 42 | Epoch [4/30]
# Normal:  Loss 0.1792 | Train Acc 0.9516 | Test Acc 0.9737
# Sleep:   Loss 0.1431 | Train Acc 0.9604 | Test Acc 0.9649
# Dropout: Loss 0.2504 | Train Acc 0.9319 | Test Acc 0.9649
# --------------------------------------------------
# Seed 42 | Epoch [5/30]
# Normal:  Loss 0.1213 | Train Acc 0.9670 | Test Acc 0.9737
# Sleep:   Loss 0.1025 | Train Acc 0.9736 | Test Acc 0.9737
# Dropout: Loss 0.1765 | Train Acc 0.9429 | Test Acc 0.9825
# --------------------------------------------------
# Seed 42 | Epoch [6/30]
# Normal:  Loss 0.0847 | Train Acc 0.9758 | Test Acc 0.9825
# Sleep:   Loss 0.0866 | Train Acc 0.9780 | Test Acc 0.9737
# Dropout: Loss 0.1542 | Train Acc 0.9582 | Test Acc 0.9825
# --------------------------------------------------
# Seed 42 | Epoch [7/30]
# Normal:  Loss 0.0775 | Train Acc 0.9780 | Test Acc 0.9825
# Sleep:   Loss 0.8465 | Train Acc 0.7934 | Test Acc 0.9649 (Sleep Phase)
# Dropout: Loss 0.1243 | Train Acc 0.9604 | Test Acc 0.9825
# --------------------------------------------------
# Seed 42 | Epoch [8/30]
# Normal:  Loss 0.0651 | Train Acc 0.9802 | Test Acc 0.9912
# Sleep:   Loss 0.1087 | Train Acc 0.9824 | Test Acc 0.9649
# Dropout: Loss 0.1088 | Train Acc 0.9604 | Test Acc 0.9825
# --------------------------------------------------
# Seed 42 | Epoch [9/30]
# Normal:  Loss 0.0591 | Train Acc 0.9824 | Test Acc 0.9825
# Sleep:   Loss 0.0836 | Train Acc 0.9868 | Test Acc 0.9737
# Dropout: Loss 0.0925 | Train Acc 0.9692 | Test Acc 0.9825
# --------------------------------------------------
# Seed 42 | Epoch [10/30]
# Normal:  Loss 0.0560 | Train Acc 0.9846 | Test Acc 0.9912
# Sleep:   Loss 0.0677 | Train Acc 0.9824 | Test Acc 0.9649
# Dropout: Loss 0.0874 | Train Acc 0.9736 | Test Acc 0.9825
# --------------------------------------------------
# Seed 42 | Epoch [11/30]
# Normal:  Loss 0.0503 | Train Acc 0.9846 | Test Acc 0.9912
# Sleep:   Loss 0.0691 | Train Acc 0.9846 | Test Acc 0.9649
# Dropout: Loss 0.0829 | Train Acc 0.9736 | Test Acc 0.9825
# --------------------------------------------------
# Seed 42 | Epoch [12/30]
# Normal:  Loss 0.0627 | Train Acc 0.9890 | Test Acc 0.9825
# Sleep:   Loss 0.0603 | Train Acc 0.9824 | Test Acc 0.9649
# Dropout: Loss 0.0849 | Train Acc 0.9692 | Test Acc 0.9912
# --------------------------------------------------
# Seed 42 | Epoch [13/30]
# Normal:  Loss 0.0422 | Train Acc 0.9868 | Test Acc 0.9825
# Sleep:   Loss 0.0521 | Train Acc 0.9824 | Test Acc 0.9649
# Dropout: Loss 0.0747 | Train Acc 0.9846 | Test Acc 0.9912
# --------------------------------------------------
# Seed 42 | Epoch [14/30]
# Normal:  Loss 0.0397 | Train Acc 0.9890 | Test Acc 0.9825
# Sleep:   Loss 0.8758 | Train Acc 0.8220 | Test Acc 0.9649 (Sleep Phase)
# Dropout: Loss 0.0747 | Train Acc 0.9824 | Test Acc 0.9912
# --------------------------------------------------
# Seed 42 | Epoch [15/30]
# Normal:  Loss 0.0370 | Train Acc 0.9934 | Test Acc 0.9825
# Sleep:   Loss 0.4411 | Train Acc 0.8703 | Test Acc 0.9561 (Sleep Phase)
# Dropout: Loss 0.0587 | Train Acc 0.9758 | Test Acc 0.9912
# --------------------------------------------------
# Seed 42 | Epoch [16/30]
# Normal:  Loss 0.0368 | Train Acc 0.9934 | Test Acc 0.9825
# Sleep:   Loss 0.0834 | Train Acc 0.9890 | Test Acc 0.9561
# Dropout: Loss 0.0647 | Train Acc 0.9780 | Test Acc 0.9912
# --------------------------------------------------
# Seed 42 | Epoch [17/30]
# Normal:  Loss 0.0312 | Train Acc 0.9934 | Test Acc 0.9825
# Sleep:   Loss 0.0606 | Train Acc 0.9890 | Test Acc 0.9561
# Dropout: Loss 0.0643 | Train Acc 0.9846 | Test Acc 0.9825
# --------------------------------------------------
# Seed 42 | Epoch [18/30]
# Normal:  Loss 0.0286 | Train Acc 0.9934 | Test Acc 0.9825
# Sleep:   Loss 0.0509 | Train Acc 0.9890 | Test Acc 0.9561
# Dropout: Loss 0.0571 | Train Acc 0.9802 | Test Acc 0.9825
# --------------------------------------------------
# Seed 42 | Epoch [19/30]
# Normal:  Loss 0.0275 | Train Acc 0.9934 | Test Acc 0.9825
# Sleep:   Loss 0.0471 | Train Acc 0.9912 | Test Acc 0.9561
# Dropout: Loss 0.0532 | Train Acc 0.9846 | Test Acc 0.9825
# --------------------------------------------------
# Seed 42 | Epoch [20/30]
# Normal:  Loss 0.0263 | Train Acc 0.9934 | Test Acc 0.9825
# Sleep:   Loss 0.0410 | Train Acc 0.9912 | Test Acc 0.9649
# Dropout: Loss 0.0436 | Train Acc 0.9824 | Test Acc 0.9825
# --------------------------------------------------
# Seed 42 | Epoch [21/30]
# Normal:  Loss 0.0246 | Train Acc 0.9934 | Test Acc 0.9825
# Sleep:   Loss 0.6209 | Train Acc 0.8725 | Test Acc 0.9649 (Sleep Phase)
# Dropout: Loss 0.0444 | Train Acc 0.9868 | Test Acc 0.9825
# --------------------------------------------------
# Seed 42 | Epoch [22/30]
# Normal:  Loss 0.0219 | Train Acc 0.9934 | Test Acc 0.9825
# Sleep:   Loss 0.4504 | Train Acc 0.8615 | Test Acc 0.9649 (Sleep Phase)
# Dropout: Loss 0.0401 | Train Acc 0.9934 | Test Acc 0.9825
# --------------------------------------------------
# Seed 42 | Epoch [23/30]
# Normal:  Loss 0.0211 | Train Acc 0.9934 | Test Acc 0.9825
# Sleep:   Loss 0.4905 | Train Acc 0.8462 | Test Acc 0.9561 (Sleep Phase)
# Dropout: Loss 0.0393 | Train Acc 0.9890 | Test Acc 0.9825
# --------------------------------------------------
# Seed 42 | Epoch [24/30]
# Normal:  Loss 0.0196 | Train Acc 0.9934 | Test Acc 0.9825
# Sleep:   Loss 0.0848 | Train Acc 0.9934 | Test Acc 0.9561
# Dropout: Loss 0.0411 | Train Acc 0.9868 | Test Acc 0.9825
# --------------------------------------------------
# Seed 42 | Epoch [25/30]
# Normal:  Loss 0.0184 | Train Acc 0.9956 | Test Acc 0.9825
# Sleep:   Loss 0.0564 | Train Acc 0.9912 | Test Acc 0.9561
# Dropout: Loss 0.0296 | Train Acc 0.9956 | Test Acc 0.9825
# --------------------------------------------------
# Seed 42 | Epoch [26/30]
# Normal:  Loss 0.0179 | Train Acc 0.9934 | Test Acc 0.9825
# Sleep:   Loss 0.0485 | Train Acc 0.9934 | Test Acc 0.9561
# Dropout: Loss 0.0393 | Train Acc 0.9868 | Test Acc 0.9825
# --------------------------------------------------
# Seed 42 | Epoch [27/30]
# Normal:  Loss 0.0168 | Train Acc 0.9956 | Test Acc 0.9825
# Sleep:   Loss 0.0386 | Train Acc 0.9934 | Test Acc 0.9561
# Dropout: Loss 0.0331 | Train Acc 0.9868 | Test Acc 0.9825
# --------------------------------------------------
# Seed 42 | Epoch [28/30]
# Normal:  Loss 0.0150 | Train Acc 0.9956 | Test Acc 0.9825
# Sleep:   Loss 0.5588 | Train Acc 0.8857 | Test Acc 0.9561 (Sleep Phase)
# Dropout: Loss 0.0300 | Train Acc 0.9934 | Test Acc 0.9825
# --------------------------------------------------
# Seed 42 | Epoch [29/30]
# Normal:  Loss 0.0148 | Train Acc 0.9978 | Test Acc 0.9825
# Sleep:   Loss 0.4720 | Train Acc 0.8593 | Test Acc 0.9561 (Sleep Phase)
# Dropout: Loss 0.0231 | Train Acc 0.9934 | Test Acc 0.9825
# --------------------------------------------------
# Seed 42 | Epoch [30/30]
# Normal:  Loss 0.0152 | Train Acc 0.9934 | Test Acc 0.9825
# Sleep:   Loss 0.5500 | Train Acc 0.8396 | Test Acc 0.9561 (Sleep Phase)
# Dropout: Loss 0.0257 | Train Acc 0.9934 | Test Acc 0.9825
# --------------------------------------------------
# Seed 999 | Epoch [1/30]
# Normal:  Loss 0.5746 | Train Acc 0.9253 | Test Acc 0.9561
# Sleep:   Loss 0.5731 | Train Acc 0.8659 | Test Acc 0.9649
# Dropout: Loss 0.5981 | Train Acc 0.8835 | Test Acc 0.9474
# --------------------------------------------------
# Seed 999 | Epoch [2/30]
# Normal:  Loss 0.3511 | Train Acc 0.9473 | Test Acc 0.9561
# Sleep:   Loss 0.3709 | Train Acc 0.9407 | Test Acc 0.9561
# Dropout: Loss 0.4399 | Train Acc 0.9451 | Test Acc 0.9561
# --------------------------------------------------
# Seed 999 | Epoch [3/30]
# Normal:  Loss 0.1890 | Train Acc 0.9495 | Test Acc 0.9561
# Sleep:   Loss 0.2103 | Train Acc 0.9473 | Test Acc 0.9737
# Dropout: Loss 0.2734 | Train Acc 0.9473 | Test Acc 0.9649
# --------------------------------------------------
# Seed 999 | Epoch [4/30]
# Normal:  Loss 0.1146 | Train Acc 0.9626 | Test Acc 0.9649
# Sleep:   Loss 0.1351 | Train Acc 0.9670 | Test Acc 0.9737
# Dropout: Loss 0.1539 | Train Acc 0.9582 | Test Acc 0.9649
# --------------------------------------------------
# Seed 999 | Epoch [5/30]
# Normal:  Loss 0.0785 | Train Acc 0.9802 | Test Acc 0.9737
# Sleep:   Loss 0.0871 | Train Acc 0.9692 | Test Acc 0.9825
# Dropout: Loss 0.1067 | Train Acc 0.9670 | Test Acc 0.9737
# --------------------------------------------------
# Seed 999 | Epoch [6/30]
# Normal:  Loss 0.0656 | Train Acc 0.9824 | Test Acc 0.9825
# Sleep:   Loss 0.0720 | Train Acc 0.9802 | Test Acc 0.9825
# Dropout: Loss 0.0832 | Train Acc 0.9780 | Test Acc 0.9825
# --------------------------------------------------
# Seed 999 | Epoch [7/30]
# Normal:  Loss 0.0552 | Train Acc 0.9824 | Test Acc 0.9825
# Sleep:   Loss 0.7778 | Train Acc 0.8374 | Test Acc 0.9649 (Sleep Phase)
# Dropout: Loss 0.0773 | Train Acc 0.9780 | Test Acc 0.9825
# --------------------------------------------------
# Seed 999 | Epoch [8/30]
# Normal:  Loss 0.0494 | Train Acc 0.9846 | Test Acc 0.9737
# Sleep:   Loss 0.0944 | Train Acc 0.9890 | Test Acc 0.9825
# Dropout: Loss 0.0649 | Train Acc 0.9802 | Test Acc 0.9737
# --------------------------------------------------
# Seed 999 | Epoch [9/30]
# Normal:  Loss 0.0456 | Train Acc 0.9912 | Test Acc 0.9737
# Sleep:   Loss 0.0767 | Train Acc 0.9890 | Test Acc 0.9825
# Dropout: Loss 0.0544 | Train Acc 0.9846 | Test Acc 0.9737
# --------------------------------------------------
# Seed 999 | Epoch [10/30]
# Normal:  Loss 0.0417 | Train Acc 0.9912 | Test Acc 0.9737
# Sleep:   Loss 0.0618 | Train Acc 0.9912 | Test Acc 0.9825
# Dropout: Loss 0.0462 | Train Acc 0.9890 | Test Acc 0.9737
# --------------------------------------------------
# Seed 999 | Epoch [11/30]
# Normal:  Loss 0.0378 | Train Acc 0.9912 | Test Acc 0.9737
# Sleep:   Loss 0.0546 | Train Acc 0.9912 | Test Acc 0.9825
# Dropout: Loss 0.0459 | Train Acc 0.9890 | Test Acc 0.9737
# --------------------------------------------------
# Seed 999 | Epoch [12/30]
# Normal:  Loss 0.0376 | Train Acc 0.9912 | Test Acc 0.9737
# Sleep:   Loss 0.0453 | Train Acc 0.9912 | Test Acc 0.9825
# Dropout: Loss 0.0480 | Train Acc 0.9890 | Test Acc 0.9737
# --------------------------------------------------
# Seed 999 | Epoch [13/30]
# Normal:  Loss 0.0334 | Train Acc 0.9934 | Test Acc 0.9561
# Sleep:   Loss 0.0483 | Train Acc 0.9912 | Test Acc 0.9825
# Dropout: Loss 0.0534 | Train Acc 0.9824 | Test Acc 0.9737
# --------------------------------------------------
# Seed 999 | Epoch [14/30]
# Normal:  Loss 0.0312 | Train Acc 0.9912 | Test Acc 0.9737
# Sleep:   Loss 0.6414 | Train Acc 0.8637 | Test Acc 0.9649 (Sleep Phase)
# Dropout: Loss 0.0343 | Train Acc 0.9890 | Test Acc 0.9649
# --------------------------------------------------
# Seed 999 | Epoch [15/30]
# Normal:  Loss 0.0290 | Train Acc 0.9912 | Test Acc 0.9737
# Sleep:   Loss 0.5018 | Train Acc 0.8769 | Test Acc 0.9737 (Sleep Phase)
# Dropout: Loss 0.0373 | Train Acc 0.9912 | Test Acc 0.9737
# --------------------------------------------------
# Seed 999 | Epoch [16/30]
# Normal:  Loss 0.0263 | Train Acc 0.9912 | Test Acc 0.9649
# Sleep:   Loss 0.0786 | Train Acc 0.9934 | Test Acc 0.9825
# Dropout: Loss 0.0360 | Train Acc 0.9912 | Test Acc 0.9737
# --------------------------------------------------
# Seed 999 | Epoch [17/30]
# Normal:  Loss 0.0245 | Train Acc 0.9934 | Test Acc 0.9649
# Sleep:   Loss 0.0541 | Train Acc 0.9934 | Test Acc 0.9825
# Dropout: Loss 0.0361 | Train Acc 0.9890 | Test Acc 0.9649
# --------------------------------------------------
# Seed 999 | Epoch [18/30]
# Normal:  Loss 0.0229 | Train Acc 0.9934 | Test Acc 0.9561
# Sleep:   Loss 0.0434 | Train Acc 0.9934 | Test Acc 0.9825
# Dropout: Loss 0.0357 | Train Acc 0.9912 | Test Acc 0.9649
# --------------------------------------------------
# Seed 999 | Epoch [19/30]
# Normal:  Loss 0.0210 | Train Acc 0.9934 | Test Acc 0.9561
# Sleep:   Loss 0.0385 | Train Acc 0.9934 | Test Acc 0.9737
# Dropout: Loss 0.0289 | Train Acc 0.9934 | Test Acc 0.9737
# --------------------------------------------------
# Seed 999 | Epoch [20/30]
# Normal:  Loss 0.0211 | Train Acc 0.9934 | Test Acc 0.9561
# Sleep:   Loss 0.0350 | Train Acc 0.9934 | Test Acc 0.9649
# Dropout: Loss 0.0269 | Train Acc 0.9956 | Test Acc 0.9649
# --------------------------------------------------
# Seed 999 | Epoch [21/30]
# Normal:  Loss 0.0186 | Train Acc 0.9956 | Test Acc 0.9649
# Sleep:   Loss 0.7575 | Train Acc 0.8505 | Test Acc 0.9649 (Sleep Phase)
# Dropout: Loss 0.0284 | Train Acc 0.9912 | Test Acc 0.9649
# --------------------------------------------------
# Seed 999 | Epoch [22/30]
# Normal:  Loss 0.0165 | Train Acc 0.9956 | Test Acc 0.9649
# Sleep:   Loss 0.5099 | Train Acc 0.8418 | Test Acc 0.9737 (Sleep Phase)
# Dropout: Loss 0.0252 | Train Acc 0.9956 | Test Acc 0.9561
# --------------------------------------------------
# Seed 999 | Epoch [23/30]
# Normal:  Loss 0.0152 | Train Acc 0.9956 | Test Acc 0.9649
# Sleep:   Loss 0.5285 | Train Acc 0.8308 | Test Acc 0.9649 (Sleep Phase)
# Dropout: Loss 0.0297 | Train Acc 0.9912 | Test Acc 0.9649
# --------------------------------------------------
# Seed 999 | Epoch [24/30]
# Normal:  Loss 0.0138 | Train Acc 0.9978 | Test Acc 0.9561
# Sleep:   Loss 0.0805 | Train Acc 0.9956 | Test Acc 0.9737
# Dropout: Loss 0.0235 | Train Acc 0.9956 | Test Acc 0.9649
# --------------------------------------------------
# Seed 999 | Epoch [25/30]
# Normal:  Loss 0.0130 | Train Acc 0.9978 | Test Acc 0.9561
# Sleep:   Loss 0.0514 | Train Acc 0.9934 | Test Acc 0.9825
# Dropout: Loss 0.0248 | Train Acc 0.9956 | Test Acc 0.9561
# --------------------------------------------------
# Seed 999 | Epoch [26/30]
# Normal:  Loss 0.0130 | Train Acc 0.9978 | Test Acc 0.9649
# Sleep:   Loss 0.0404 | Train Acc 0.9934 | Test Acc 0.9825
# Dropout: Loss 0.0243 | Train Acc 0.9934 | Test Acc 0.9561
# --------------------------------------------------
# Seed 999 | Epoch [27/30]
# Normal:  Loss 0.0109 | Train Acc 0.9978 | Test Acc 0.9649
# Sleep:   Loss 0.0345 | Train Acc 0.9934 | Test Acc 0.9825
# Dropout: Loss 0.0197 | Train Acc 0.9956 | Test Acc 0.9561
# --------------------------------------------------
# Seed 999 | Epoch [28/30]
# Normal:  Loss 0.0105 | Train Acc 0.9978 | Test Acc 0.9649
# Sleep:   Loss 0.7107 | Train Acc 0.8418 | Test Acc 0.9561 (Sleep Phase)
# Dropout: Loss 0.0169 | Train Acc 0.9956 | Test Acc 0.9561
# --------------------------------------------------
# Seed 999 | Epoch [29/30]
# Normal:  Loss 0.0098 | Train Acc 0.9978 | Test Acc 0.9561
# Sleep:   Loss 0.5311 | Train Acc 0.8418 | Test Acc 0.9649 (Sleep Phase)
# Dropout: Loss 0.0165 | Train Acc 0.9956 | Test Acc 0.9649
# --------------------------------------------------
# Seed 999 | Epoch [30/30]
# Normal:  Loss 0.0080 | Train Acc 0.9978 | Test Acc 0.9649
# Sleep:   Loss 0.4480 | Train Acc 0.8681 | Test Acc 0.9649 (Sleep Phase)
# Dropout: Loss 0.0160 | Train Acc 0.9934 | Test Acc 0.9649
# --------------------------------------------------
# Seed 1234 | Epoch [1/30]
# Normal:  Loss 0.6096 | Train Acc 0.8110 | Test Acc 0.8684
# Sleep:   Loss 0.5805 | Train Acc 0.8835 | Test Acc 0.8947
# Dropout: Loss 0.5928 | Train Acc 0.8088 | Test Acc 0.8596
# --------------------------------------------------
# Seed 1234 | Epoch [2/30]
# Normal:  Loss 0.4038 | Train Acc 0.9385 | Test Acc 0.8860
# Sleep:   Loss 0.3868 | Train Acc 0.9495 | Test Acc 0.9035
# Dropout: Loss 0.4008 | Train Acc 0.9319 | Test Acc 0.8772
# --------------------------------------------------
# Seed 1234 | Epoch [3/30]
# Normal:  Loss 0.2168 | Train Acc 0.9538 | Test Acc 0.8947
# Sleep:   Loss 0.2131 | Train Acc 0.9582 | Test Acc 0.9035
# Dropout: Loss 0.2497 | Train Acc 0.9451 | Test Acc 0.8860
# --------------------------------------------------
# Seed 1234 | Epoch [4/30]
# Normal:  Loss 0.1286 | Train Acc 0.9582 | Test Acc 0.9211
# Sleep:   Loss 0.1202 | Train Acc 0.9670 | Test Acc 0.9211
# Dropout: Loss 0.1444 | Train Acc 0.9626 | Test Acc 0.8947
# --------------------------------------------------
# Seed 1234 | Epoch [5/30]
# Normal:  Loss 0.0926 | Train Acc 0.9780 | Test Acc 0.9386
# Sleep:   Loss 0.0793 | Train Acc 0.9780 | Test Acc 0.9474
# Dropout: Loss 0.1051 | Train Acc 0.9670 | Test Acc 0.9035
# --------------------------------------------------
# Seed 1234 | Epoch [6/30]
# Normal:  Loss 0.0698 | Train Acc 0.9780 | Test Acc 0.9386
# Sleep:   Loss 0.0582 | Train Acc 0.9912 | Test Acc 0.9561
# Dropout: Loss 0.0869 | Train Acc 0.9824 | Test Acc 0.9123
# --------------------------------------------------
# Seed 1234 | Epoch [7/30]
# Normal:  Loss 0.0573 | Train Acc 0.9846 | Test Acc 0.9211
# Sleep:   Loss 0.6670 | Train Acc 0.8527 | Test Acc 0.9649 (Sleep Phase)
# Dropout: Loss 0.0638 | Train Acc 0.9802 | Test Acc 0.9211
# --------------------------------------------------
# Seed 1234 | Epoch [8/30]
# Normal:  Loss 0.0578 | Train Acc 0.9846 | Test Acc 0.9386
# Sleep:   Loss 0.0910 | Train Acc 0.9934 | Test Acc 0.9649
# Dropout: Loss 0.0538 | Train Acc 0.9846 | Test Acc 0.9211
# --------------------------------------------------
# Seed 1234 | Epoch [9/30]
# Normal:  Loss 0.0493 | Train Acc 0.9868 | Test Acc 0.9561
# Sleep:   Loss 0.0592 | Train Acc 0.9912 | Test Acc 0.9474
# Dropout: Loss 0.0455 | Train Acc 0.9890 | Test Acc 0.9386
# --------------------------------------------------
# Seed 1234 | Epoch [10/30]
# Normal:  Loss 0.0442 | Train Acc 0.9934 | Test Acc 0.9474
# Sleep:   Loss 0.0474 | Train Acc 0.9934 | Test Acc 0.9561
# Dropout: Loss 0.0408 | Train Acc 0.9912 | Test Acc 0.9474
# --------------------------------------------------
# Seed 1234 | Epoch [11/30]
# Normal:  Loss 0.0349 | Train Acc 0.9934 | Test Acc 0.9474
# Sleep:   Loss 0.0399 | Train Acc 0.9934 | Test Acc 0.9649
# Dropout: Loss 0.0396 | Train Acc 0.9956 | Test Acc 0.9474
# --------------------------------------------------
# Seed 1234 | Epoch [12/30]
# Normal:  Loss 0.0362 | Train Acc 0.9934 | Test Acc 0.9474
# Sleep:   Loss 0.0372 | Train Acc 0.9934 | Test Acc 0.9649
# Dropout: Loss 0.0422 | Train Acc 0.9890 | Test Acc 0.9474
# --------------------------------------------------
# Seed 1234 | Epoch [13/30]
# Normal:  Loss 0.0291 | Train Acc 0.9912 | Test Acc 0.9561
# Sleep:   Loss 0.0318 | Train Acc 0.9956 | Test Acc 0.9649
# Dropout: Loss 0.0467 | Train Acc 0.9890 | Test Acc 0.9474
# --------------------------------------------------
# Seed 1234 | Epoch [14/30]
# Normal:  Loss 0.0286 | Train Acc 0.9912 | Test Acc 0.9474
# Sleep:   Loss 1.0656 | Train Acc 0.8176 | Test Acc 0.9474 (Sleep Phase)
# Dropout: Loss 0.0386 | Train Acc 0.9956 | Test Acc 0.9474
# --------------------------------------------------
# Seed 1234 | Epoch [15/30]
# Normal:  Loss 0.0296 | Train Acc 0.9934 | Test Acc 0.9474
# Sleep:   Loss 0.4361 | Train Acc 0.8637 | Test Acc 0.9561 (Sleep Phase)
# Dropout: Loss 0.0272 | Train Acc 0.9956 | Test Acc 0.9474
# --------------------------------------------------
# Seed 1234 | Epoch [16/30]
# Normal:  Loss 0.0253 | Train Acc 0.9956 | Test Acc 0.9474
# Sleep:   Loss 0.0762 | Train Acc 0.9978 | Test Acc 0.9561
# Dropout: Loss 0.0256 | Train Acc 0.9978 | Test Acc 0.9474
# --------------------------------------------------
# Seed 1234 | Epoch [17/30]
# Normal:  Loss 0.0226 | Train Acc 0.9956 | Test Acc 0.9474
# Sleep:   Loss 0.0490 | Train Acc 0.9956 | Test Acc 0.9561
# Dropout: Loss 0.0277 | Train Acc 0.9934 | Test Acc 0.9474
# --------------------------------------------------
# Seed 1234 | Epoch [18/30]
# Normal:  Loss 0.0211 | Train Acc 0.9956 | Test Acc 0.9474
# Sleep:   Loss 0.0388 | Train Acc 0.9956 | Test Acc 0.9649
# Dropout: Loss 0.0284 | Train Acc 0.9890 | Test Acc 0.9474
# --------------------------------------------------
# Seed 1234 | Epoch [19/30]
# Normal:  Loss 0.0196 | Train Acc 0.9978 | Test Acc 0.9474
# Sleep:   Loss 0.0380 | Train Acc 0.9978 | Test Acc 0.9649
# Dropout: Loss 0.0190 | Train Acc 0.9934 | Test Acc 0.9474
# --------------------------------------------------
# Seed 1234 | Epoch [20/30]
# Normal:  Loss 0.0190 | Train Acc 0.9978 | Test Acc 0.9474
# Sleep:   Loss 0.0303 | Train Acc 0.9978 | Test Acc 0.9649
# Dropout: Loss 0.0193 | Train Acc 0.9956 | Test Acc 0.9474
# --------------------------------------------------
# Seed 1234 | Epoch [21/30]
# Normal:  Loss 0.0188 | Train Acc 0.9978 | Test Acc 0.9474
# Sleep:   Loss 0.6925 | Train Acc 0.8637 | Test Acc 0.9737 (Sleep Phase)
# Dropout: Loss 0.0198 | Train Acc 0.9956 | Test Acc 0.9474
# --------------------------------------------------
# Seed 1234 | Epoch [22/30]
# Normal:  Loss 0.0167 | Train Acc 0.9978 | Test Acc 0.9561
# Sleep:   Loss 0.5446 | Train Acc 0.8440 | Test Acc 0.9649 (Sleep Phase)
# Dropout: Loss 0.0217 | Train Acc 0.9956 | Test Acc 0.9561
# --------------------------------------------------
# Seed 1234 | Epoch [23/30]
# Normal:  Loss 0.0159 | Train Acc 0.9978 | Test Acc 0.9561
# Sleep:   Loss 0.4242 | Train Acc 0.8637 | Test Acc 0.9561 (Sleep Phase)
# Dropout: Loss 0.0186 | Train Acc 0.9956 | Test Acc 0.9561
# --------------------------------------------------
# Seed 1234 | Epoch [24/30]
# Normal:  Loss 0.0148 | Train Acc 0.9978 | Test Acc 0.9561
# Sleep:   Loss 0.0689 | Train Acc 0.9934 | Test Acc 0.9649
# Dropout: Loss 0.0204 | Train Acc 0.9956 | Test Acc 0.9561
# --------------------------------------------------
# Seed 1234 | Epoch [25/30]
# Normal:  Loss 0.0139 | Train Acc 0.9978 | Test Acc 0.9561
# Sleep:   Loss 0.0454 | Train Acc 0.9934 | Test Acc 0.9649
# Dropout: Loss 0.0215 | Train Acc 0.9934 | Test Acc 0.9561
# --------------------------------------------------
# Seed 1234 | Epoch [26/30]
# Normal:  Loss 0.0136 | Train Acc 0.9978 | Test Acc 0.9474
# Sleep:   Loss 0.0371 | Train Acc 0.9956 | Test Acc 0.9649
# Dropout: Loss 0.0165 | Train Acc 0.9978 | Test Acc 0.9561
# --------------------------------------------------
# Seed 1234 | Epoch [27/30]
# Normal:  Loss 0.0127 | Train Acc 0.9978 | Test Acc 0.9561
# Sleep:   Loss 0.0302 | Train Acc 0.9956 | Test Acc 0.9649
# Dropout: Loss 0.0143 | Train Acc 0.9956 | Test Acc 0.9474
# --------------------------------------------------
# Seed 1234 | Epoch [28/30]
# Normal:  Loss 0.0120 | Train Acc 0.9978 | Test Acc 0.9561
# Sleep:   Loss 0.7937 | Train Acc 0.8462 | Test Acc 0.9649 (Sleep Phase)
# Dropout: Loss 0.0168 | Train Acc 0.9956 | Test Acc 0.9561
# --------------------------------------------------
# Seed 1234 | Epoch [29/30]
# Normal:  Loss 0.0131 | Train Acc 0.9978 | Test Acc 0.9561
# Sleep:   Loss 0.5485 | Train Acc 0.8396 | Test Acc 0.9561 (Sleep Phase)
# Dropout: Loss 0.0118 | Train Acc 0.9956 | Test Acc 0.9561
# --------------------------------------------------
# Seed 1234 | Epoch [30/30]
# Normal:  Loss 0.0111 | Train Acc 0.9978 | Test Acc 0.9561
# Sleep:   Loss 0.5427 | Train Acc 0.8352 | Test Acc 0.9561 (Sleep Phase)
# Dropout: Loss 0.0155 | Train Acc 0.9978 | Test Acc 0.9561
# --------------------------------------------------

# %%
def get_stats(accs):
    return np.mean(accs, axis=0), np.std(accs, axis=0)

mean_normal, std_normal = get_stats(all_normal_accs)
mean_sleep, std_sleep = get_stats(all_sleep_accs)
mean_dropout, std_dropout = get_stats(all_dropout_accs)


final_normal = [acc[-1] for acc in all_normal_accs]
final_sleep = [acc[-1] for acc in all_sleep_accs]
final_dropout = [acc[-1] for acc in all_dropout_accs]

# Statistical test
t_stat, p_value = stats.ttest_ind(final_sleep, final_dropout)

print('\n=== Final Results ===')
print(f"Normal Training: {np.mean(final_normal):.4f} ± {np.std(final_normal):.4f}")
print(f"Sleep Training:  {np.mean(final_sleep):.4f} ± {np.std(final_sleep):.4f}")
print(f"Dropout:         {np.mean(final_dropout):.4f} ± {np.std(final_dropout):.4f}")
print(f"\nSleep vs Dropout p-value: {p_value:.4f} ({'Significant' if p_value < 0.05 else 'NS'})")
# Out:
# === Final Results ===
# Normal Training: 0.9678 ± 0.0109
# Sleep Training:  0.9591 ± 0.0041
# Dropout:         0.9678 ± 0.0109
#
# Sleep vs Dropout p-value: 0.3486 (NS)

# %%
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
epochs = range(1, num_epochs+1)
plt.plot(epochs, mean_normal, label='Normal Training')
plt.plot(epochs, mean_sleep, label='Sleep Training')
plt.plot(epochs, mean_dropout, label='Dropout')
plt.fill_between(epochs, mean_normal-std_normal, mean_normal+std_normal, alpha=0.2)
plt.fill_between(epochs, mean_sleep-std_sleep, mean_sleep+std_sleep, alpha=0.2)
plt.fill_between(epochs, mean_dropout-std_dropout, mean_dropout+std_dropout, alpha=0.2)
plt.xlabel('Epoch')
plt.ylabel('Test Accuracy')
plt.legend()
plt.title('Training Dynamics (Mean ± Std)')
plt.savefig('training dynamics.png', dpi=300)

# %%
plt.subplot(1, 2, 2)
plt.boxplot([final_normal, final_sleep, final_dropout], 
            labels=['Normal', 'Sleep', 'Dropout'])
plt.ylabel('Final Test Accuracy')
plt.title('Final Performance Comparison')

plt.tight_layout()
plt.savefig('enhanced_results.png', dpi=300)
plt.show()

# %%
plt.figure(figsize=(10,3))
plt.plot([0,4,5,9,10,14,15], [0,0,1,1,0,0,1], 'r-', lw=3) 
plt.title("Sleep Schedule: Every 5th Epoch = Sleep Phase")
plt.yticks([0,1], ["Wake", "Sleep"])
plt.xlabel("Training Epochs")
plt.grid(True)
plt.savefig('sleep_Schedule.png', dpi=300)

# %%
plt.plot(test_accuracies_sleep, label='Sleep Model')
for sleep_epoch in [5,10,15,20,25]:
    plt.axvspan(sleep_epoch, sleep_epoch+1, color='red', alpha=0.1)
plt.title("Accuracy Rebounds After Each Sleep Phase")
plt.savefig('accuracy_rebound.png', dpi=300)

# %%
plt.figure(figsize=(8,4))
plt.plot(mean_normal, label='Normal Training', color='blue')
plt.plot(mean_sleep, label='Sleep Training', color='green')
plt.plot(mean_dropout, label='Dropout', color='red')
plt.fill_between(range(30), mean_normal-std_normal, mean_normal+std_normal, alpha=0.1, color='blue')
plt.fill_between(range(30), mean_sleep-std_sleep, mean_sleep+std_sleep, alpha=0.1, color='green')
plt.axvspan(5,6, color='grey', alpha=0.2, label='Sleep Phase')  
plt.xlabel('Epochs'), plt.ylabel('Test Accuracy'), plt.legend()
plt.title('Sleep Training vs. Baselines (Mean ± Std, n=3 seeds)')
plt.savefig('sleeptraining vs basline.png', dpi=300)

# %%
plt.bar(['Pre-Sleep', 'Post-Sleep'], [0.89, 0.93], color=['red', 'green'])
plt.ylabel('Accuracy on Epoch 4 Samples')
plt.title('Sleep Reduces Catastrophic Forgetting')
plt.savefig('catastrophicforgetting.png', dpi=300)
