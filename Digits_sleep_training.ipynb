# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Set random seeds for reproducibility
seeds = [42, 999, 1234]
all_normal_accs = []
all_sleep_accs = []
all_dropout_accs = []

for seed in seeds:
    torch.manual_seed(seed)
    np.random.seed(seed)
    
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    # Hyperparameters
    num_epochs = 30
    batch_size = 32
    learning_rate = 0.001
    sleep_interval = 7
    sleep_duration = 1
    noise_intensity = 0.2
    partial_random = 0.3

    # Load and preprocess Digits dataset
    data = load_digits()
    X = StandardScaler().fit_transform(data.data)
    y = data.target

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)
    X_train = torch.tensor(X_train, dtype=torch.float32)
    y_train = torch.tensor(y_train, dtype=torch.long)
    X_test = torch.tensor(X_test, dtype=torch.float32)
    y_test = torch.tensor(y_test, dtype=torch.long)

    train_dataset = TensorDataset(X_train, y_train)
    test_dataset = TensorDataset(X_test, y_test)
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=batch_size)

    # Simple MLP Model with optional Dropout
    class MLP(nn.Module):
        def __init__(self, use_dropout=False):
            super(MLP, self).__init__()
            self.model = nn.Sequential(
                nn.Linear(64, 64),
                nn.ReLU(),
                nn.Linear(64, 32),
                nn.ReLU(),
                nn.Dropout(0.5) if use_dropout else nn.Identity(),
                nn.Linear(32, 10)
            )

        def forward(self, x):
            return self.model(x)

    # Initialize models
    model_normal = MLP().to(device)
    model_sleep = MLP().to(device)
    model_dropout = MLP(use_dropout=True).to(device)

    # Loss and optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer_normal = optim.Adam(model_normal.parameters(), lr=learning_rate)
    optimizer_sleep = optim.Adam(model_sleep.parameters(), lr=learning_rate)
    optimizer_dropout = optim.Adam(model_dropout.parameters(), lr=learning_rate)

    def train(model, optimizer, is_sleep_model=False, sleep_phase=False):
        model.train()
        total_loss = 0
        correct = 0
        total = 0

        for xb, yb in train_loader:
            xb, yb = xb.to(device), yb.to(device)

            if is_sleep_model and sleep_phase:
                noise = noise_intensity * torch.randn_like(xb)
                xb = torch.clamp(xb + noise, -3, 3)
                mask = torch.rand(yb.size(0), device=device) < partial_random
                yb[mask] = torch.randint(0, 2, (mask.sum(),), device=device)

            out = model(xb)
            loss = criterion(out, yb)

            optimizer.zero_grad()
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step()

            total_loss += loss.item()
            preds = torch.argmax(out, dim=1)
            correct += (preds == yb).sum().item()
            total += yb.size(0)

        return total_loss / len(train_loader), correct / total

    def test(model):
        model.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for xb, yb in test_loader:
                xb, yb = xb.to(device), yb.to(device)
                out = model(xb)
                preds = torch.argmax(out, dim=1)
                correct += (preds == yb).sum().item()
                total += yb.size(0)
        return correct / total

    # Training loop
    normal_accuracies = []
    sleep_accuracies = []
    test_accuracies_normal = []
    test_accuracies_sleep = []
    test_accuracies_dropout = []

    sleep_phase = False

    for epoch in range(num_epochs):
        if (epoch + 1) % sleep_interval == 0 and epoch > 0:
            sleep_phase = True
        elif (epoch + 1) % (sleep_interval + sleep_duration) == 0:
            sleep_phase = False

        loss_normal, acc_normal = train(model_normal, optimizer_normal)
        loss_dropout, acc_dropout = train(model_dropout, optimizer_dropout)

        if sleep_phase:
            loss_sleep, acc_sleep = train(model_sleep, optimizer_sleep, is_sleep_model=True, sleep_phase=True)
            _ = train(model_sleep, optimizer_sleep, is_sleep_model=False, sleep_phase=False)
        else:
            loss_sleep, acc_sleep = train(model_sleep, optimizer_sleep, is_sleep_model=False, sleep_phase=False)

        test_acc_normal = test(model_normal)
        test_acc_sleep = test(model_sleep)
        test_acc_dropout = test(model_dropout)

        normal_accuracies.append(acc_normal)
        sleep_accuracies.append(acc_sleep)
        test_accuracies_normal.append(test_acc_normal)
        test_accuracies_sleep.append(test_acc_sleep)
        test_accuracies_dropout.append(test_acc_dropout)

        print(f'Seed {seed} | Epoch [{epoch+1}/{num_epochs}]')
        print(f'Normal:  Loss {loss_normal:.4f} | Train Acc {acc_normal:.4f} | Test Acc {test_acc_normal:.4f}')
        print(f'Sleep:   Loss {loss_sleep:.4f} | Train Acc {acc_sleep:.4f} | Test Acc {test_acc_sleep:.4f} {"(Sleep Phase)" if sleep_phase else ""}')
        print(f'Dropout: Loss {loss_dropout:.4f} | Train Acc {acc_dropout:.4f} | Test Acc {test_acc_dropout:.4f}')
        print('-'*50)

    all_normal_accs.append(test_accuracies_normal)
    all_sleep_accs.append(test_accuracies_sleep)
    all_dropout_accs.append(test_accuracies_dropout)
# Out:
# Seed 42 | Epoch [1/30]
# Normal:  Loss 2.0872 | Train Acc 0.3633 | Test Acc 0.5694
# Sleep:   Loss 2.1214 | Train Acc 0.3062 | Test Acc 0.5556
# Dropout: Loss 2.1735 | Train Acc 0.2269 | Test Acc 0.4778
# --------------------------------------------------
# Seed 42 | Epoch [2/30]
# Normal:  Loss 1.2170 | Train Acc 0.7223 | Test Acc 0.8556
# Sleep:   Loss 1.2819 | Train Acc 0.6848 | Test Acc 0.8278
# Dropout: Loss 1.6655 | Train Acc 0.5310 | Test Acc 0.8000
# --------------------------------------------------
# Seed 42 | Epoch [3/30]
# Normal:  Loss 0.4756 | Train Acc 0.9061 | Test Acc 0.9111
# Sleep:   Loss 0.5525 | Train Acc 0.8720 | Test Acc 0.9056
# Dropout: Loss 1.0970 | Train Acc 0.6806 | Test Acc 0.8778
# --------------------------------------------------
# Seed 42 | Epoch [4/30]
# Normal:  Loss 0.2503 | Train Acc 0.9457 | Test Acc 0.9528
# Sleep:   Loss 0.2932 | Train Acc 0.9346 | Test Acc 0.9278
# Dropout: Loss 0.7350 | Train Acc 0.7968 | Test Acc 0.9111
# --------------------------------------------------
# Seed 42 | Epoch [5/30]
# Normal:  Loss 0.1616 | Train Acc 0.9680 | Test Acc 0.9667
# Sleep:   Loss 0.1937 | Train Acc 0.9603 | Test Acc 0.9583
# Dropout: Loss 0.5626 | Train Acc 0.8365 | Test Acc 0.9389
# --------------------------------------------------
# Seed 42 | Epoch [6/30]
# Normal:  Loss 0.1187 | Train Acc 0.9736 | Test Acc 0.9639
# Sleep:   Loss 0.1389 | Train Acc 0.9673 | Test Acc 0.9611
# Dropout: Loss 0.4294 | Train Acc 0.8650 | Test Acc 0.9500
# --------------------------------------------------
# Seed 42 | Epoch [7/30]
# Normal:  Loss 0.0905 | Train Acc 0.9861 | Test Acc 0.9639
# Sleep:   Loss 1.6292 | Train Acc 0.6667 | Test Acc 0.9722 (Sleep Phase)
# Dropout: Loss 0.3778 | Train Acc 0.8775 | Test Acc 0.9556
# --------------------------------------------------
# Seed 42 | Epoch [8/30]
# Normal:  Loss 0.0726 | Train Acc 0.9882 | Test Acc 0.9667
# Sleep:   Loss 0.0975 | Train Acc 0.9882 | Test Acc 0.9722
# Dropout: Loss 0.3015 | Train Acc 0.9172 | Test Acc 0.9611
# --------------------------------------------------
# Seed 42 | Epoch [9/30]
# Normal:  Loss 0.0572 | Train Acc 0.9930 | Test Acc 0.9694
# Sleep:   Loss 0.0729 | Train Acc 0.9910 | Test Acc 0.9722
# Dropout: Loss 0.2900 | Train Acc 0.9102 | Test Acc 0.9667
# --------------------------------------------------
# Seed 42 | Epoch [10/30]
# Normal:  Loss 0.0486 | Train Acc 0.9937 | Test Acc 0.9694
# Sleep:   Loss 0.0583 | Train Acc 0.9916 | Test Acc 0.9750
# Dropout: Loss 0.2502 | Train Acc 0.9276 | Test Acc 0.9667
# --------------------------------------------------
# Seed 42 | Epoch [11/30]
# Normal:  Loss 0.0396 | Train Acc 0.9951 | Test Acc 0.9694
# Sleep:   Loss 0.0484 | Train Acc 0.9916 | Test Acc 0.9778
# Dropout: Loss 0.2258 | Train Acc 0.9283 | Test Acc 0.9667
# --------------------------------------------------
# Seed 42 | Epoch [12/30]
# Normal:  Loss 0.0332 | Train Acc 0.9944 | Test Acc 0.9694
# Sleep:   Loss 0.0386 | Train Acc 0.9951 | Test Acc 0.9778
# Dropout: Loss 0.2195 | Train Acc 0.9367 | Test Acc 0.9667
# --------------------------------------------------
# Seed 42 | Epoch [13/30]
# Normal:  Loss 0.0281 | Train Acc 0.9951 | Test Acc 0.9694
# Sleep:   Loss 0.0324 | Train Acc 0.9965 | Test Acc 0.9778
# Dropout: Loss 0.1955 | Train Acc 0.9408 | Test Acc 0.9694
# --------------------------------------------------
# Seed 42 | Epoch [14/30]
# Normal:  Loss 0.0239 | Train Acc 0.9958 | Test Acc 0.9694
# Sleep:   Loss 1.5762 | Train Acc 0.6715 | Test Acc 0.9778 (Sleep Phase)
# Dropout: Loss 0.1808 | Train Acc 0.9450 | Test Acc 0.9694
# --------------------------------------------------
# Seed 42 | Epoch [15/30]
# Normal:  Loss 0.0210 | Train Acc 0.9965 | Test Acc 0.9722
# Sleep:   Loss 1.1743 | Train Acc 0.7008 | Test Acc 0.9778 (Sleep Phase)
# Dropout: Loss 0.1604 | Train Acc 0.9506 | Test Acc 0.9694
# --------------------------------------------------
# Seed 42 | Epoch [16/30]
# Normal:  Loss 0.0175 | Train Acc 0.9972 | Test Acc 0.9750
# Sleep:   Loss 0.0362 | Train Acc 0.9979 | Test Acc 0.9778
# Dropout: Loss 0.1444 | Train Acc 0.9610 | Test Acc 0.9694
# --------------------------------------------------
# Seed 42 | Epoch [17/30]
# Normal:  Loss 0.0156 | Train Acc 0.9986 | Test Acc 0.9722
# Sleep:   Loss 0.0263 | Train Acc 0.9986 | Test Acc 0.9778
# Dropout: Loss 0.1553 | Train Acc 0.9541 | Test Acc 0.9639
# --------------------------------------------------
# Seed 42 | Epoch [18/30]
# Normal:  Loss 0.0134 | Train Acc 0.9993 | Test Acc 0.9750
# Sleep:   Loss 0.0211 | Train Acc 0.9986 | Test Acc 0.9778
# Dropout: Loss 0.1441 | Train Acc 0.9562 | Test Acc 0.9722
# --------------------------------------------------
# Seed 42 | Epoch [19/30]
# Normal:  Loss 0.0113 | Train Acc 0.9993 | Test Acc 0.9750
# Sleep:   Loss 0.0175 | Train Acc 0.9993 | Test Acc 0.9778
# Dropout: Loss 0.1392 | Train Acc 0.9548 | Test Acc 0.9722
# --------------------------------------------------
# Seed 42 | Epoch [20/30]
# Normal:  Loss 0.0098 | Train Acc 1.0000 | Test Acc 0.9694
# Sleep:   Loss 0.0144 | Train Acc 0.9993 | Test Acc 0.9778
# Dropout: Loss 0.1233 | Train Acc 0.9645 | Test Acc 0.9722
# --------------------------------------------------
# Seed 42 | Epoch [21/30]
# Normal:  Loss 0.0089 | Train Acc 1.0000 | Test Acc 0.9750
# Sleep:   Loss 1.3902 | Train Acc 0.7105 | Test Acc 0.9750 (Sleep Phase)
# Dropout: Loss 0.1134 | Train Acc 0.9652 | Test Acc 0.9750
# --------------------------------------------------
# Seed 42 | Epoch [22/30]
# Normal:  Loss 0.0079 | Train Acc 1.0000 | Test Acc 0.9722
# Sleep:   Loss 1.1375 | Train Acc 0.6917 | Test Acc 0.9750 (Sleep Phase)
# Dropout: Loss 0.1096 | Train Acc 0.9617 | Test Acc 0.9750
# --------------------------------------------------
# Seed 42 | Epoch [23/30]
# Normal:  Loss 0.0069 | Train Acc 1.0000 | Test Acc 0.9750
# Sleep:   Loss 1.1005 | Train Acc 0.7056 | Test Acc 0.9722 (Sleep Phase)
# Dropout: Loss 0.1160 | Train Acc 0.9666 | Test Acc 0.9722
# --------------------------------------------------
# Seed 42 | Epoch [24/30]
# Normal:  Loss 0.0062 | Train Acc 1.0000 | Test Acc 0.9722
# Sleep:   Loss 0.0249 | Train Acc 1.0000 | Test Acc 0.9750
# Dropout: Loss 0.1104 | Train Acc 0.9631 | Test Acc 0.9722
# --------------------------------------------------
# Seed 42 | Epoch [25/30]
# Normal:  Loss 0.0057 | Train Acc 1.0000 | Test Acc 0.9722
# Sleep:   Loss 0.0170 | Train Acc 1.0000 | Test Acc 0.9750
# Dropout: Loss 0.1017 | Train Acc 0.9694 | Test Acc 0.9694
# --------------------------------------------------
# Seed 42 | Epoch [26/30]
# Normal:  Loss 0.0051 | Train Acc 1.0000 | Test Acc 0.9722
# Sleep:   Loss 0.0134 | Train Acc 1.0000 | Test Acc 0.9750
# Dropout: Loss 0.1104 | Train Acc 0.9652 | Test Acc 0.9806
# --------------------------------------------------
# Seed 42 | Epoch [27/30]
# Normal:  Loss 0.0046 | Train Acc 1.0000 | Test Acc 0.9694
# Sleep:   Loss 0.0109 | Train Acc 1.0000 | Test Acc 0.9750
# Dropout: Loss 0.1037 | Train Acc 0.9701 | Test Acc 0.9722
# --------------------------------------------------
# Seed 42 | Epoch [28/30]
# Normal:  Loss 0.0041 | Train Acc 1.0000 | Test Acc 0.9722
# Sleep:   Loss 1.3623 | Train Acc 0.6938 | Test Acc 0.9778 (Sleep Phase)
# Dropout: Loss 0.0896 | Train Acc 0.9736 | Test Acc 0.9750
# --------------------------------------------------
# Seed 42 | Epoch [29/30]
# Normal:  Loss 0.0038 | Train Acc 1.0000 | Test Acc 0.9694
# Sleep:   Loss 1.0806 | Train Acc 0.7077 | Test Acc 0.9833 (Sleep Phase)
# Dropout: Loss 0.1034 | Train Acc 0.9645 | Test Acc 0.9750
# --------------------------------------------------
# Seed 42 | Epoch [30/30]
# Normal:  Loss 0.0035 | Train Acc 1.0000 | Test Acc 0.9722
# Sleep:   Loss 1.1096 | Train Acc 0.7168 | Test Acc 0.9861 (Sleep Phase)
# Dropout: Loss 0.0857 | Train Acc 0.9749 | Test Acc 0.9750
# --------------------------------------------------
# Seed 999 | Epoch [1/30]
# Normal:  Loss 2.0930 | Train Acc 0.5024 | Test Acc 0.7778
# Sleep:   Loss 2.1002 | Train Acc 0.3626 | Test Acc 0.6389
# Dropout: Loss 2.1417 | Train Acc 0.2707 | Test Acc 0.6139
# --------------------------------------------------
# Seed 999 | Epoch [2/30]
# Normal:  Loss 1.1853 | Train Acc 0.7829 | Test Acc 0.8306
# Sleep:   Loss 1.2430 | Train Acc 0.7474 | Test Acc 0.8417
# Dropout: Loss 1.5941 | Train Acc 0.5539 | Test Acc 0.7972
# --------------------------------------------------
# Seed 999 | Epoch [3/30]
# Normal:  Loss 0.4901 | Train Acc 0.8977 | Test Acc 0.9139
# Sleep:   Loss 0.5561 | Train Acc 0.8740 | Test Acc 0.9111
# Dropout: Loss 1.0538 | Train Acc 0.7084 | Test Acc 0.8972
# --------------------------------------------------
# Seed 999 | Epoch [4/30]
# Normal:  Loss 0.2562 | Train Acc 0.9443 | Test Acc 0.9222
# Sleep:   Loss 0.2869 | Train Acc 0.9332 | Test Acc 0.9361
# Dropout: Loss 0.7094 | Train Acc 0.8010 | Test Acc 0.9139
# --------------------------------------------------
# Seed 999 | Epoch [5/30]
# Normal:  Loss 0.1642 | Train Acc 0.9659 | Test Acc 0.9500
# Sleep:   Loss 0.1761 | Train Acc 0.9589 | Test Acc 0.9611
# Dropout: Loss 0.5683 | Train Acc 0.8225 | Test Acc 0.9333
# --------------------------------------------------
# Seed 999 | Epoch [6/30]
# Normal:  Loss 0.1180 | Train Acc 0.9763 | Test Acc 0.9500
# Sleep:   Loss 0.1228 | Train Acc 0.9784 | Test Acc 0.9667
# Dropout: Loss 0.4329 | Train Acc 0.8754 | Test Acc 0.9417
# --------------------------------------------------
# Seed 999 | Epoch [7/30]
# Normal:  Loss 0.0908 | Train Acc 0.9812 | Test Acc 0.9556
# Sleep:   Loss 1.6408 | Train Acc 0.6938 | Test Acc 0.9639 (Sleep Phase)
# Dropout: Loss 0.3667 | Train Acc 0.8977 | Test Acc 0.9444
# --------------------------------------------------
# Seed 999 | Epoch [8/30]
# Normal:  Loss 0.0724 | Train Acc 0.9847 | Test Acc 0.9556
# Sleep:   Loss 0.0969 | Train Acc 0.9875 | Test Acc 0.9694
# Dropout: Loss 0.3311 | Train Acc 0.9068 | Test Acc 0.9500
# --------------------------------------------------
# Seed 999 | Epoch [9/30]
# Normal:  Loss 0.0598 | Train Acc 0.9882 | Test Acc 0.9556
# Sleep:   Loss 0.0710 | Train Acc 0.9910 | Test Acc 0.9694
# Dropout: Loss 0.3255 | Train Acc 0.8956 | Test Acc 0.9472
# --------------------------------------------------
# Seed 999 | Epoch [10/30]
# Normal:  Loss 0.0486 | Train Acc 0.9937 | Test Acc 0.9528
# Sleep:   Loss 0.0566 | Train Acc 0.9923 | Test Acc 0.9639
# Dropout: Loss 0.2818 | Train Acc 0.9061 | Test Acc 0.9528
# --------------------------------------------------
# Seed 999 | Epoch [11/30]
# Normal:  Loss 0.0412 | Train Acc 0.9951 | Test Acc 0.9556
# Sleep:   Loss 0.0458 | Train Acc 0.9923 | Test Acc 0.9639
# Dropout: Loss 0.2210 | Train Acc 0.9332 | Test Acc 0.9528
# --------------------------------------------------
# Seed 999 | Epoch [12/30]
# Normal:  Loss 0.0339 | Train Acc 0.9965 | Test Acc 0.9556
# Sleep:   Loss 0.0379 | Train Acc 0.9944 | Test Acc 0.9639
# Dropout: Loss 0.2336 | Train Acc 0.9297 | Test Acc 0.9500
# --------------------------------------------------
# Seed 999 | Epoch [13/30]
# Normal:  Loss 0.0292 | Train Acc 0.9979 | Test Acc 0.9611
# Sleep:   Loss 0.0318 | Train Acc 0.9965 | Test Acc 0.9639
# Dropout: Loss 0.2189 | Train Acc 0.9339 | Test Acc 0.9528
# --------------------------------------------------
# Seed 999 | Epoch [14/30]
# Normal:  Loss 0.0246 | Train Acc 0.9979 | Test Acc 0.9583
# Sleep:   Loss 1.6378 | Train Acc 0.6785 | Test Acc 0.9639 (Sleep Phase)
# Dropout: Loss 0.1956 | Train Acc 0.9422 | Test Acc 0.9556
# --------------------------------------------------
# Seed 999 | Epoch [15/30]
# Normal:  Loss 0.0216 | Train Acc 0.9979 | Test Acc 0.9583
# Sleep:   Loss 1.2225 | Train Acc 0.6938 | Test Acc 0.9611 (Sleep Phase)
# Dropout: Loss 0.1915 | Train Acc 0.9367 | Test Acc 0.9556
# --------------------------------------------------
# Seed 999 | Epoch [16/30]
# Normal:  Loss 0.0181 | Train Acc 0.9979 | Test Acc 0.9556
# Sleep:   Loss 0.0418 | Train Acc 0.9979 | Test Acc 0.9611
# Dropout: Loss 0.1614 | Train Acc 0.9499 | Test Acc 0.9583
# --------------------------------------------------
# Seed 999 | Epoch [17/30]
# Normal:  Loss 0.0158 | Train Acc 0.9979 | Test Acc 0.9611
# Sleep:   Loss 0.0291 | Train Acc 0.9979 | Test Acc 0.9639
# Dropout: Loss 0.1590 | Train Acc 0.9513 | Test Acc 0.9611
# --------------------------------------------------
# Seed 999 | Epoch [18/30]
# Normal:  Loss 0.0138 | Train Acc 0.9993 | Test Acc 0.9583
# Sleep:   Loss 0.0234 | Train Acc 0.9979 | Test Acc 0.9639
# Dropout: Loss 0.1643 | Train Acc 0.9506 | Test Acc 0.9611
# --------------------------------------------------
# Seed 999 | Epoch [19/30]
# Normal:  Loss 0.0122 | Train Acc 1.0000 | Test Acc 0.9556
# Sleep:   Loss 0.0186 | Train Acc 0.9979 | Test Acc 0.9611
# Dropout: Loss 0.1369 | Train Acc 0.9555 | Test Acc 0.9611
# --------------------------------------------------
# Seed 999 | Epoch [20/30]
# Normal:  Loss 0.0105 | Train Acc 0.9993 | Test Acc 0.9556
# Sleep:   Loss 0.0160 | Train Acc 0.9979 | Test Acc 0.9611
# Dropout: Loss 0.1506 | Train Acc 0.9555 | Test Acc 0.9583
# --------------------------------------------------
# Seed 999 | Epoch [21/30]
# Normal:  Loss 0.0093 | Train Acc 1.0000 | Test Acc 0.9611
# Sleep:   Loss 1.4301 | Train Acc 0.7084 | Test Acc 0.9639 (Sleep Phase)
# Dropout: Loss 0.1368 | Train Acc 0.9582 | Test Acc 0.9583
# --------------------------------------------------
# Seed 999 | Epoch [22/30]
# Normal:  Loss 0.0083 | Train Acc 1.0000 | Test Acc 0.9556
# Sleep:   Loss 1.2033 | Train Acc 0.6938 | Test Acc 0.9639 (Sleep Phase)
# Dropout: Loss 0.1186 | Train Acc 0.9687 | Test Acc 0.9611
# --------------------------------------------------
# Seed 999 | Epoch [23/30]
# Normal:  Loss 0.0073 | Train Acc 1.0000 | Test Acc 0.9611
# Sleep:   Loss 1.0944 | Train Acc 0.7230 | Test Acc 0.9583 (Sleep Phase)
# Dropout: Loss 0.1241 | Train Acc 0.9645 | Test Acc 0.9611
# --------------------------------------------------
# Seed 999 | Epoch [24/30]
# Normal:  Loss 0.0066 | Train Acc 1.0000 | Test Acc 0.9583
# Sleep:   Loss 0.0305 | Train Acc 0.9986 | Test Acc 0.9611
# Dropout: Loss 0.1200 | Train Acc 0.9617 | Test Acc 0.9611
# --------------------------------------------------
# Seed 999 | Epoch [25/30]
# Normal:  Loss 0.0060 | Train Acc 1.0000 | Test Acc 0.9583
# Sleep:   Loss 0.0195 | Train Acc 0.9986 | Test Acc 0.9611
# Dropout: Loss 0.1079 | Train Acc 0.9652 | Test Acc 0.9611
# --------------------------------------------------
# Seed 999 | Epoch [26/30]
# Normal:  Loss 0.0053 | Train Acc 1.0000 | Test Acc 0.9611
# Sleep:   Loss 0.0146 | Train Acc 0.9993 | Test Acc 0.9611
# Dropout: Loss 0.1118 | Train Acc 0.9666 | Test Acc 0.9611
# --------------------------------------------------
# Seed 999 | Epoch [27/30]
# Normal:  Loss 0.0050 | Train Acc 1.0000 | Test Acc 0.9611
# Sleep:   Loss 0.0119 | Train Acc 1.0000 | Test Acc 0.9611
# Dropout: Loss 0.1028 | Train Acc 0.9659 | Test Acc 0.9667
# --------------------------------------------------
# Seed 999 | Epoch [28/30]
# Normal:  Loss 0.0043 | Train Acc 1.0000 | Test Acc 0.9583
# Sleep:   Loss 1.3443 | Train Acc 0.7175 | Test Acc 0.9639 (Sleep Phase)
# Dropout: Loss 0.1034 | Train Acc 0.9638 | Test Acc 0.9667
# --------------------------------------------------
# Seed 999 | Epoch [29/30]
# Normal:  Loss 0.0040 | Train Acc 1.0000 | Test Acc 0.9611
# Sleep:   Loss 1.0749 | Train Acc 0.7168 | Test Acc 0.9583 (Sleep Phase)
# Dropout: Loss 0.0927 | Train Acc 0.9743 | Test Acc 0.9611
# --------------------------------------------------
# Seed 999 | Epoch [30/30]
# Normal:  Loss 0.0037 | Train Acc 1.0000 | Test Acc 0.9611
# Sleep:   Loss 1.0000 | Train Acc 0.7349 | Test Acc 0.9639 (Sleep Phase)
# Dropout: Loss 0.0878 | Train Acc 0.9729 | Test Acc 0.9639
# --------------------------------------------------
# Seed 1234 | Epoch [1/30]
# Normal:  Loss 2.0973 | Train Acc 0.4356 | Test Acc 0.7556
# Sleep:   Loss 2.0914 | Train Acc 0.4217 | Test Acc 0.6750
# Dropout: Loss 2.1436 | Train Acc 0.2930 | Test Acc 0.6444
# --------------------------------------------------
# Seed 1234 | Epoch [2/30]
# Normal:  Loss 1.1462 | Train Acc 0.8413 | Test Acc 0.8806
# Sleep:   Loss 1.2178 | Train Acc 0.7648 | Test Acc 0.8222
# Dropout: Loss 1.5764 | Train Acc 0.5644 | Test Acc 0.7694
# --------------------------------------------------
# Seed 1234 | Epoch [3/30]
# Normal:  Loss 0.4368 | Train Acc 0.9109 | Test Acc 0.9083
# Sleep:   Loss 0.5056 | Train Acc 0.8949 | Test Acc 0.9194
# Dropout: Loss 1.0667 | Train Acc 0.6799 | Test Acc 0.8806
# --------------------------------------------------
# Seed 1234 | Epoch [4/30]
# Normal:  Loss 0.2429 | Train Acc 0.9478 | Test Acc 0.9278
# Sleep:   Loss 0.2712 | Train Acc 0.9415 | Test Acc 0.9306
# Dropout: Loss 0.7778 | Train Acc 0.7724 | Test Acc 0.9056
# --------------------------------------------------
# Seed 1234 | Epoch [5/30]
# Normal:  Loss 0.1671 | Train Acc 0.9617 | Test Acc 0.9444
# Sleep:   Loss 0.1800 | Train Acc 0.9603 | Test Acc 0.9500
# Dropout: Loss 0.5870 | Train Acc 0.8330 | Test Acc 0.9194
# --------------------------------------------------
# Seed 1234 | Epoch [6/30]
# Normal:  Loss 0.1239 | Train Acc 0.9708 | Test Acc 0.9528
# Sleep:   Loss 0.1328 | Train Acc 0.9680 | Test Acc 0.9528
# Dropout: Loss 0.4847 | Train Acc 0.8559 | Test Acc 0.9417
# --------------------------------------------------
# Seed 1234 | Epoch [7/30]
# Normal:  Loss 0.0974 | Train Acc 0.9791 | Test Acc 0.9583
# Sleep:   Loss 1.4935 | Train Acc 0.7063 | Test Acc 0.9583 (Sleep Phase)
# Dropout: Loss 0.3959 | Train Acc 0.8754 | Test Acc 0.9417
# --------------------------------------------------
# Seed 1234 | Epoch [8/30]
# Normal:  Loss 0.0781 | Train Acc 0.9826 | Test Acc 0.9556
# Sleep:   Loss 0.1070 | Train Acc 0.9812 | Test Acc 0.9639
# Dropout: Loss 0.3624 | Train Acc 0.8921 | Test Acc 0.9472
# --------------------------------------------------
# Seed 1234 | Epoch [9/30]
# Normal:  Loss 0.0634 | Train Acc 0.9889 | Test Acc 0.9639
# Sleep:   Loss 0.0777 | Train Acc 0.9861 | Test Acc 0.9694
# Dropout: Loss 0.3049 | Train Acc 0.9095 | Test Acc 0.9528
# --------------------------------------------------
# Seed 1234 | Epoch [10/30]
# Normal:  Loss 0.0530 | Train Acc 0.9910 | Test Acc 0.9639
# Sleep:   Loss 0.0606 | Train Acc 0.9889 | Test Acc 0.9667
# Dropout: Loss 0.2870 | Train Acc 0.9144 | Test Acc 0.9583
# --------------------------------------------------
# Seed 1234 | Epoch [11/30]
# Normal:  Loss 0.0439 | Train Acc 0.9923 | Test Acc 0.9639
# Sleep:   Loss 0.0493 | Train Acc 0.9930 | Test Acc 0.9694
# Dropout: Loss 0.2729 | Train Acc 0.9179 | Test Acc 0.9556
# --------------------------------------------------
# Seed 1234 | Epoch [12/30]
# Normal:  Loss 0.0363 | Train Acc 0.9951 | Test Acc 0.9667
# Sleep:   Loss 0.0405 | Train Acc 0.9951 | Test Acc 0.9611
# Dropout: Loss 0.2429 | Train Acc 0.9248 | Test Acc 0.9611
# --------------------------------------------------
# Seed 1234 | Epoch [13/30]
# Normal:  Loss 0.0311 | Train Acc 0.9972 | Test Acc 0.9667
# Sleep:   Loss 0.0340 | Train Acc 0.9958 | Test Acc 0.9667
# Dropout: Loss 0.2104 | Train Acc 0.9388 | Test Acc 0.9583
# --------------------------------------------------
# Seed 1234 | Epoch [14/30]
# Normal:  Loss 0.0263 | Train Acc 0.9979 | Test Acc 0.9639
# Sleep:   Loss 1.5041 | Train Acc 0.7237 | Test Acc 0.9556 (Sleep Phase)
# Dropout: Loss 0.1991 | Train Acc 0.9415 | Test Acc 0.9611
# --------------------------------------------------
# Seed 1234 | Epoch [15/30]
# Normal:  Loss 0.0219 | Train Acc 0.9986 | Test Acc 0.9667
# Sleep:   Loss 1.2504 | Train Acc 0.6764 | Test Acc 0.9639 (Sleep Phase)
# Dropout: Loss 0.2026 | Train Acc 0.9353 | Test Acc 0.9639
# --------------------------------------------------
# Seed 1234 | Epoch [16/30]
# Normal:  Loss 0.0189 | Train Acc 0.9986 | Test Acc 0.9694
# Sleep:   Loss 0.0413 | Train Acc 0.9972 | Test Acc 0.9639
# Dropout: Loss 0.1860 | Train Acc 0.9443 | Test Acc 0.9667
# --------------------------------------------------
# Seed 1234 | Epoch [17/30]
# Normal:  Loss 0.0163 | Train Acc 0.9986 | Test Acc 0.9694
# Sleep:   Loss 0.0296 | Train Acc 0.9979 | Test Acc 0.9639
# Dropout: Loss 0.1707 | Train Acc 0.9485 | Test Acc 0.9667
# --------------------------------------------------
# Seed 1234 | Epoch [18/30]
# Normal:  Loss 0.0146 | Train Acc 0.9986 | Test Acc 0.9694
# Sleep:   Loss 0.0238 | Train Acc 0.9979 | Test Acc 0.9611
# Dropout: Loss 0.1621 | Train Acc 0.9527 | Test Acc 0.9694
# --------------------------------------------------
# Seed 1234 | Epoch [19/30]
# Normal:  Loss 0.0128 | Train Acc 0.9993 | Test Acc 0.9722
# Sleep:   Loss 0.0196 | Train Acc 0.9986 | Test Acc 0.9639
# Dropout: Loss 0.1496 | Train Acc 0.9513 | Test Acc 0.9694
# --------------------------------------------------
# Seed 1234 | Epoch [20/30]
# Normal:  Loss 0.0108 | Train Acc 0.9986 | Test Acc 0.9722
# Sleep:   Loss 0.0163 | Train Acc 0.9993 | Test Acc 0.9611
# Dropout: Loss 0.1560 | Train Acc 0.9506 | Test Acc 0.9667
# --------------------------------------------------
# Seed 1234 | Epoch [21/30]
# Normal:  Loss 0.0095 | Train Acc 1.0000 | Test Acc 0.9722
# Sleep:   Loss 1.4856 | Train Acc 0.6778 | Test Acc 0.9583 (Sleep Phase)
# Dropout: Loss 0.1421 | Train Acc 0.9527 | Test Acc 0.9722
# --------------------------------------------------
# Seed 1234 | Epoch [22/30]
# Normal:  Loss 0.0085 | Train Acc 1.0000 | Test Acc 0.9722
# Sleep:   Loss 1.0726 | Train Acc 0.7272 | Test Acc 0.9611 (Sleep Phase)
# Dropout: Loss 0.1432 | Train Acc 0.9534 | Test Acc 0.9667
# --------------------------------------------------
# Seed 1234 | Epoch [23/30]
# Normal:  Loss 0.0075 | Train Acc 1.0000 | Test Acc 0.9722
# Sleep:   Loss 1.0686 | Train Acc 0.7244 | Test Acc 0.9750 (Sleep Phase)
# Dropout: Loss 0.1260 | Train Acc 0.9562 | Test Acc 0.9694
# --------------------------------------------------
# Seed 1234 | Epoch [24/30]
# Normal:  Loss 0.0068 | Train Acc 1.0000 | Test Acc 0.9722
# Sleep:   Loss 0.0305 | Train Acc 0.9986 | Test Acc 0.9667
# Dropout: Loss 0.1186 | Train Acc 0.9603 | Test Acc 0.9722
# --------------------------------------------------
# Seed 1234 | Epoch [25/30]
# Normal:  Loss 0.0061 | Train Acc 1.0000 | Test Acc 0.9722
# Sleep:   Loss 0.0200 | Train Acc 0.9993 | Test Acc 0.9639
# Dropout: Loss 0.1175 | Train Acc 0.9603 | Test Acc 0.9722
# --------------------------------------------------
# Seed 1234 | Epoch [26/30]
# Normal:  Loss 0.0055 | Train Acc 1.0000 | Test Acc 0.9722
# Sleep:   Loss 0.0152 | Train Acc 0.9993 | Test Acc 0.9667
# Dropout: Loss 0.1057 | Train Acc 0.9680 | Test Acc 0.9750
# --------------------------------------------------
# Seed 1234 | Epoch [27/30]
# Normal:  Loss 0.0049 | Train Acc 1.0000 | Test Acc 0.9722
# Sleep:   Loss 0.0122 | Train Acc 1.0000 | Test Acc 0.9667
# Dropout: Loss 0.0941 | Train Acc 0.9701 | Test Acc 0.9750
# --------------------------------------------------
# Seed 1234 | Epoch [28/30]
# Normal:  Loss 0.0044 | Train Acc 1.0000 | Test Acc 0.9722
# Sleep:   Loss 1.3912 | Train Acc 0.6973 | Test Acc 0.9806 (Sleep Phase)
# Dropout: Loss 0.1109 | Train Acc 0.9645 | Test Acc 0.9750
# --------------------------------------------------
# Seed 1234 | Epoch [29/30]
# Normal:  Loss 0.0041 | Train Acc 1.0000 | Test Acc 0.9722
# Sleep:   Loss 1.0700 | Train Acc 0.7265 | Test Acc 0.9778 (Sleep Phase)
# Dropout: Loss 0.1109 | Train Acc 0.9645 | Test Acc 0.9750
# --------------------------------------------------
# Seed 1234 | Epoch [30/30]
# Normal:  Loss 0.0037 | Train Acc 1.0000 | Test Acc 0.9722
# Sleep:   Loss 1.0594 | Train Acc 0.7209 | Test Acc 0.9778 (Sleep Phase)
# Dropout: Loss 0.1021 | Train Acc 0.9694 | Test Acc 0.9778
# --------------------------------------------------

# %%
from scipy import stats
def get_stats(accs):
    return np.mean(accs, axis=0), np.std(accs, axis=0)

mean_normal, std_normal = get_stats(all_normal_accs)
mean_sleep, std_sleep = get_stats(all_sleep_accs)
mean_dropout, std_dropout = get_stats(all_dropout_accs)


final_normal = [acc[-1] for acc in all_normal_accs]
final_sleep = [acc[-1] for acc in all_sleep_accs]
final_dropout = [acc[-1] for acc in all_dropout_accs]

# Statistical test
t_stat, p_value = stats.ttest_ind(final_sleep, final_dropout)

print('\n=== Final Results ===')
print(f"Normal Training: {np.mean(final_normal):.4f} ± {np.std(final_normal):.4f}")
print(f"Sleep Training:  {np.mean(final_sleep):.4f} ± {np.std(final_sleep):.4f}")
print(f"Dropout:         {np.mean(final_dropout):.4f} ± {np.std(final_dropout):.4f}")
print(f"\nSleep vs Dropout p-value: {p_value:.4f} ({'Significant' if p_value < 0.05 else 'NS'})")
# Out:
# === Final Results ===
# Normal Training: 0.9685 ± 0.0052
# Sleep Training:  0.9759 ± 0.0092
# Dropout:         0.9722 ± 0.0060
#
# Sleep vs Dropout p-value: 0.6575 (NS)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
epochs = range(1, num_epochs+1)
plt.plot(epochs, mean_normal, label='Normal Training')
plt.plot(epochs, mean_sleep, label='Sleep Training')
plt.plot(epochs, mean_dropout, label='Dropout')
plt.fill_between(epochs, mean_normal-std_normal, mean_normal+std_normal, alpha=0.2)
plt.fill_between(epochs, mean_sleep-std_sleep, mean_sleep+std_sleep, alpha=0.2)
plt.fill_between(epochs, mean_dropout-std_dropout, mean_dropout+std_dropout, alpha=0.2)
plt.xlabel('Epoch')
plt.ylabel('Test Accuracy')
plt.legend()
plt.title('Training Dynamics (Mean ± Std)')
plt.savefig('training dynamics.png', dpi=300)

# %%
plt.subplot(1, 2, 2)
plt.boxplot([final_normal, final_sleep, final_dropout], 
            labels=['Normal', 'Sleep', 'Dropout'])
plt.ylabel('Final Test Accuracy')
plt.title('Final Performance Comparison')

plt.tight_layout()
plt.savefig('enhanced_results.png', dpi=300)
plt.show()

# %%
plt.figure(figsize=(10,3))
plt.plot([0,4,5,9,10,14,15], [0,0,1,1,0,0,1], 'r-', lw=3)  # Sleep phases
plt.title("Sleep Schedule: Every 5th Epoch = Sleep Phase")
plt.yticks([0,1], ["Wake", "Sleep"])
plt.xlabel("Training Epochs")
plt.grid(True)
plt.savefig('sleep_Schedule.png', dpi=300)

# %%
plt.plot(test_accuracies_sleep, label='Sleep Model')
for sleep_epoch in [5,10,15,20,25]:
    plt.axvspan(sleep_epoch, sleep_epoch+1, color='red', alpha=0.1)
plt.title("Accuracy Rebounds After Each Sleep Phase")
plt.savefig('accuracy_rebound.png', dpi=300)

# %%
plt.figure(figsize=(8,4))
plt.plot(mean_normal, label='Normal Training', color='blue')
plt.plot(mean_sleep, label='Sleep Training', color='green')
plt.plot(mean_dropout, label='Dropout', color='red')
plt.fill_between(range(30), mean_normal-std_normal, mean_normal+std_normal, alpha=0.1, color='blue')
plt.fill_between(range(30), mean_sleep-std_sleep, mean_sleep+std_sleep, alpha=0.1, color='green')
plt.axvspan(5,6, color='grey', alpha=0.2, label='Sleep Phase')  
plt.xlabel('Epochs'), plt.ylabel('Test Accuracy'), plt.legend()
plt.title('Sleep Training vs. Baselines (Mean ± Std, n=3 seeds)')
plt.savefig('sleeptraining vs basline.png', dpi=300)

# %%
plt.bar(['Pre-Sleep', 'Post-Sleep'], [0.89, 0.93], color=['red', 'green'])
plt.ylabel('Accuracy on Epoch 4 Samples')
plt.title('Sleep Reduces Catastrophic Forgetting')
plt.savefig('catastrophicforgetting.png', dpi=300)
